# %%
from datasets import Dataset
import json
from PIL import Image
import os
def load_jsonl_dataset(jsonl_path):
    with open(jsonl_path, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]
        data = data[:]
    return Dataset.from_list(data)

def load_json_dataset(json_path):
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    return data


from PIL import Image, ImageDraw, ImageFont

def draw_bboxes(
    img,
    bboxes: list,
    labels: list | None = None,
    colors: list | None = None,
    save_path: str | None = None,
    line_width: int = 3,
    font_path: str | None = None,
    font_size: int = 16,
):
    """
    在图片上绘制 bounding boxes。

    参数
    ----
    bboxes : list[tuple[int, int, int, int]]
        每个 bounding box 以 (xmin, ymin, xmax, ymax) 像素坐标表示。
    labels : list[str] | None
        与 bboxes 对应的文本标签（例如类名或置信度）。可省略。
    colors : list[str] | None
        每个框的颜色（任意 Pillow 认识的颜色字符串或 RGB 元组）。长度与 bboxes 相同，缺省则自动循环常用色。
    save_path : str | None
        保存路径；若为 None 则只返回 Image 对象，不落盘。
    line_width : int
        框线宽度。
    font_path : str | None
        字体文件路径；缺省时 Pillow 会用默认位图字体，可能不支持中文。
    font_size : int
        标签字号。
    """
    draw = ImageDraw.Draw(img)

    # 颜色准备
    default_palette = ["red", "lime", "blue", "yellow", "cyan", "magenta", "orange"]
    if colors is None:
        colors = [default_palette[i % len(default_palette)] for i in range(len(bboxes))]

    # 字体准备
    if labels:
        if font_path:
            font = ImageFont.truetype(font_path, font_size)
        else:
            # 某些 Pillow 版本的默认字体不支持中文；如需中文请显式指定 font_path
            font = ImageFont.load_default()

    # 主循环
    for i, (xmin, ymin, xmax, ymax) in enumerate(bboxes):
        color = colors[i]
        draw.rectangle([xmin, ymin, xmax, ymax], outline=color, width=line_width)

        if labels and i < len(labels):
            text = labels[i]
            text_size = draw.textlength(text, font=font)
            text_height = font.getbbox(text)[3] - font.getbbox(text)[1]
            # 文字背景框
            draw.rectangle(
                [xmin, ymin - text_height - 4, xmin + text_size + 6, ymin],
                fill=color,
            )
            # 文字
            draw.text(
                (xmin + 3, ymin - text_height - 2),
                text,
                fill="black",
                font=font,
            )

    if save_path:
        img.save(save_path)
        print(f"结果已保存到: {save_path}")
    return img

def draw_line(
    img,
    pt1: tuple[int, int],
    pt2: tuple[int, int],
    color: str | tuple[int, int, int] = "red",
    width: int = 3,
    save_path: str | None = None,
    canvas_size: tuple[int, int] | None = None,
    bg_color: str | tuple[int, int, int] = "white",
) -> Image.Image:
    """
    给定两点坐标，在图片上画线。

    参数
    ----
    pt1, pt2 : (x, y)
        线段两端点坐标，像素单位。
    color : str | RGB
        线条颜色；可用 Pillow 支持的任何颜色名称或 (R,G,B) 元组。
    width : int
        线宽（像素）。
    save_path : str | None
        若指定则保存到该路径，否则只返回 Image 对象。
    canvas_size : (w, h) | None
        当 img_path 为 None 时必须指定，用于创建空白画布的尺寸。
    bg_color : str | RGB
        新建画布时的背景色。
    """
    draw = ImageDraw.Draw(img)
    draw.line([pt1, pt2], fill=color, width=width)

    if save_path:
        img.save(save_path)
        print(f"已保存到 {save_path}")

    return img


def abstract_visual_token_single_input_images_preprocess_function(sample, dataset_root):
    
    if 'PixelReasoner' in dataset_root:
        conversations = [
            
            {
                "role": "user",
                "content": [
                    {"type": "image", "image": image},
                    {"type": "text", "text": sample["question"]},
                ],
            }
        ]
        qid = sample["qid"]
        image = Image.open(os.path.join(dataset_root, sample["image"])).convert("RGB")
        width, height = image.size
        image.save(f"./debug_output/step_image_{qid}.jpg")
        # Format conversations
        print(sample["question"])
        steps = sample["response_steps"]
        for step in steps:
            step_content = [
                        {"type": "text", "text": step["response_str"]},
                    ]
            print(step["response_str"])
            if step["manipulation"]:
                if step["manipulation"]["type"] == "crop":
                    if "<abs_vis_token>" in step["response_str"]:
                        bbox_norm = step["manipulation"]["parameters"]
                        print(bbox_norm)
                        x_min = int(bbox_norm[0] * width)
                        y_min = int(bbox_norm[1] * height)
                        x_max = int(bbox_norm[2] * width)
                        y_max = int(bbox_norm[3] * height)
                        step_content.append({"type": "image", "image": image.crop((x_min, y_min, x_max, y_max))})
                    
                        image.crop((x_min, y_min, x_max, y_max)).save(f"./debug_output/step_image_{qid}_{steps.index(step)}.jpg")
                        conversations.append({
                            "role": "assistant",
                            "content": step_content
                        })
    elif "CoM" in dataset_root:
        
        qid = sample["qid"]
        image = Image.open(os.path.join(dataset_root, sample["image"])).convert("RGB")
        width, height = image.size
        # Format conversations
        conversations = [
            {
                "role": "user",
                "content": [
                    {"type": "image", "image": image},
                    {"type": "text", "text": sample["question"]},
                ],
            }
        ]
        
        steps = sample["response_steps"]
        

        print(qid, "[Question]",sample["question"], "[Answer]",sample["answer"])
        for i, step in enumerate(steps):
            step_content = [
                        {"type": "text", "text": step["response_str"]},
                    ]
            print("[Response]",step["response_str"])
            if step["manipulation"]:
                print(i, step["manipulation"]["type"])
                if step["manipulation"]["type"] == "crop_and_zoomin":
                    bbox = step["manipulation"]["parameters"]
                    #print(bbox)
                    x_min, y_min, x_max, y_max = bbox
                    image = image.crop((x_min, y_min, x_max, y_max))
                    step_content.append({"type": "image", "image": image})

                elif step["manipulation"]["type"] == "grounding":
                    bboxes = step["manipulation"]["parameters"]
                    if bboxes is None:
                        return None
                    print(bboxes)
                    if not isinstance(bboxes[0], list):
                        bboxes = [bboxes]
                    image = draw_bboxes(image, bboxes=bboxes)
    
                elif step["manipulation"]["type"] == "line":
                    pts = step["manipulation"]["parameters"]
                    print(pts)
                    if pts[2] - pts[0] < pts[3] - pts[1]:
                        pts[2] = pts[0]
                    else:
                        pts[3] = pts[1]
                    image = draw_line(image, (pts[0], pts[1]), (pts[2], pts[3]))
                    
                image.save(f"./debug_output/CoM/step_image_{qid}_{steps.index(step)}.jpg")
            conversations.append({
                        "role": "assistant",
                        "content": step_content
                    })
    elif 'CoF' in dataset_root:
        def get_bbox_and_rmv_tool(text: str):
            s = text.find("<tool_call>")
            e = text.find("</tool_call>")
            if s == -1 or e == -1:
                return None, text
            tool_call_str = text[s+len("<tool_call>"):e]
            bbox = json.loads(tool_call_str)["arguments"]["bbox_2d"]
            return bbox, text[:s]
            
        if len(sample['images']) < 2:
            return None
        
        input_image_path = sample["images"][0]
        qid = int(input_image_path.split('/')[0])
        steps = sample['messages']
        input_image = Image.open(os.path.join(dataset_root, 'images', input_image_path)).convert("RGB")
        question = steps[1]["content"]
        input_image.save(f"./debug_output/CoF/step_image_{qid}_0.jpg")
        print(qid, "[Question]",question)
        conversations = [
            {
                "role": "user",
                "content": [
                    {"type": "image", "image": input_image},
                    {"type": "text", "text": question},
                ],
            }
        ]
        
        img_id = 1
        for step in steps[2:]:
            if step["role"] == "user":
                continue
            
            bbox, resp_wo_tool = get_bbox_and_rmv_tool(step["content"])
            print("[Response]",resp_wo_tool)
            if bbox is not None:
                image = Image.open(os.path.join(dataset_root, 'images', sample["images"][img_id])).convert("RGB")
                image.save(f"./debug_output/CoF/step_image_{qid}_{steps.index(step)}.jpg")
                img_id += 1
            step_content = [
                {"type": "text", "text": resp_wo_tool}
            ]

            
            

    return conversations

data_name = "CoM"
data_mapping = {
    "PixelReasoner": {
        "data_path": "/data1/qxwang/datasets/multimodal/PixelReasoner-SFT-Data/processed_data.json",
        "dataset_root": "/data1/qxwang/datasets/multimodal/PixelReasoner-SFT-Data"
    },
    "CoM": {
        "data_path": "/data1/qxwang/datasets/multimodal/CoMDataset/com_math_processed.jsonl",
        "dataset_root": "/data1/qxwang/datasets/multimodal/CoMDataset"
    },
    "CoF": {
        "data_path": "/data1/qxwang/datasets/multimodal/CoF-SFT-Data-5.4k/cof_sft_data.json",
        "dataset_root": "/data1/qxwang/datasets/multimodal/CoF-SFT-Data-5.4k"
    }
}

data_path = data_mapping[data_name]["data_path"]
dataset_root = data_mapping[data_name]["dataset_root"]
train_dataset = load_json_dataset(data_path)

preprocess_function = abstract_visual_token_single_input_images_preprocess_function
train_dataset = [x for x in [preprocess_function(sample, dataset_root) for sample in train_dataset[0:20]] if x is not None]
# Out:
# 0 [Question] What is the lowest accuracy reported in the whole chart? [Answer] 1
# [Response] First, find the location of the bush-troop in the image. <abs_vis_token></abs_vis_token>
# 0 grounding
# [[231, 154, 262, 218]]
# [Response] Then, draw a line segment from the leftmost side of the bush-troop. <abs_vis_token></abs_vis_token>
# 1 line
# [235, 220, 240, 337]
# [Response] Then, draw segments from the rightmost side of the bush-troop. <abs_vis_token></abs_vis_token>
# 2 line
# [258, 220, 264, 340]
# [Response] Your output: Then, locate the position of the intersection points of the Line on the image with the horizontal axis. <abs_vis_token></abs_vis_token>
# 3 grounding
# [[226, 297, 248, 322], [250, 297, 270, 322]]
# [Response] Output: It can be known that the length of the "bush-troop" is 1.
# [Response] So I can understand that the answer is 1.
# 1 [Question] Move the ruler to measure the length of the nail to the nearest inch. The nail is about (_) inches long. [Answer] 2
# [Response] Draw the leftmost vertical line of the nail. <abs_vis_token></abs_vis_token>
# 0 line
# [69, 0, 75, 157]
# [Response] Draw the rightmost vertical line of the nail. <abs_vis_token></abs_vis_token>
# 1 line
# [197, 6, 203, 157]
# [Response] Locate the scale of the ruler in the image. <abs_vis_token></abs_vis_token>
# 2 grounding
# [[16, 81, 430, 143]]
# [Response] The length of the nail is about 2 inches, so the answer is 2.
# 2 [Question] At which Episode ID does the Retroformer attain its peak Success rate (%)?
# Choices:
# (A) 1.0
# (B) 1.5
# (C) 2.0
# (D) 2.5
# (E) 3.0
# (F) 3.5
# (G) 4.0 [Answer] 4.0
# [Response] First, locate the position of the Retroformer data points in the image.
# [Response] Then, compare the positions of all Retroformer data points, and you can tell that the data point on the far right has the highest position.
# [Response] Then, draw a Line segment through the rightmost point. <abs_vis_token></abs_vis_token>
# 2 line
# [1108, 126, 1150, 618]
# [Response] Then, locate the position of the intersection point of the Line with the horizontal axis in the image. <abs_vis_token></abs_vis_token>
# 3 grounding
# 3 [Question] What is the accuracy of the algorithm with lowest accuracy? [Answer] 1
# [Response] Your output: Firstly, find the least accurate algorithm in the diagram, which is globe. <abs_vis_token></abs_vis_token>
# 0 grounding
# [[21, 258, 125, 305]]
# [Response] Secondly, find the value corresponding to the least accurate algorithm in the diagram, which is 1. <abs_vis_token></abs_vis_token>
# 1 line
# [121, 200, 126, 600]
# [Response] So the final answer is 1.
# 4 [Question] Which country has its hours worked value between 1.8k and 1.9k? [Answer] My Translation:
# Belgium, New Zealand.
# [Response] Draw a straight line to obtain the new image. <abs_vis_token></abs_vis_token>
# 0 line
# [0, 308, 858, 318]
# [Response] Draw a straight line to obtain the new image. <abs_vis_token></abs_vis_token>
# 1 line
# [0, 270, 858, 280]
# [Response] Outline all the polyline graphs between the two straight lines in the areas between New Zealand and Belgium.
# [Response] The hourly wage values in Belgium and New Zealand fall between 1.8k and 1.9k, so the answer is Belgium and New Zealand.
# 5 [Question] Is the value of Niger in 2010 larger than the average value of Madagascar and Guinea in 2010? [Answer] Yes.
# [Response] First, obtain the positions of all the curves in the graph. <abs_vis_token></abs_vis_token>
# 0 grounding
# [[0, 229, 772, 284], [0, 132, 810, 195], [0, 353, 797, 395]]
# [Response] Output: Obtain the position of the y-axis.
# [Response] Draw a straight line at the year 2010 on the Niger curve. <abs_vis_token></abs_vis_token>
# 2 line
# [15, 271, 93, 280]
# [Response] Draw a straight line at the year 2010 on the Madagascar curve. <abs_vis_token></abs_vis_token>
# 3 line
# [0, 180, 85, 189]
# [Response] Draw a straight line at the year 2010 on the Guinea curve. <abs_vis_token></abs_vis_token>
# 4 line
# [4, 385, 88, 394]
# [Response] Your output: Based on the comparison of the position relationship between the three lines and the y-axis, compare their positions.
# [Response] I understand that Niger's value in 2010 was approximately 14.5, while Madagascar and Guinea were around 19 and 7.5, respectively, in 2010.
# [Response] The calculation shows that the average of Madagascar and Guinea in 2010 is (19 + 7.5) / 2 = 13.25.
# [Response] Niger's value in 2010 was greater than the average of Madagascar and Guinea in 2010, so the answer is yes.
# 6 [Question] How many types have been considered? [Answer] nine
# [Response] First, locate the images of 10 bar charts in the figure. <abs_vis_token></abs_vis_token>
# 0 grounding
# [[140, 377, 339, 419], [45, 341, 343, 383], [205, 303, 344, 345], [128, 267, 376, 307], [135, 227, 369, 270], [134, 189, 410, 232], [101, 149, 425, 185], [206, 111, 478, 154], [186, 71, 580, 118], [28, 35, 698, 80]]
# [Response] Draw a straight line to obtain the new image after the line is drawn. <abs_vis_token></abs_vis_token>
# 1 line
# [583, 5, 592, 484]
# [Response] Output: Based on the comparison, it was found that the values of 9 shapes did not exceed 25.
# [Response] So the answer is nine.
# 7 [Question] What is the value of the largest bar? [Answer] 9
# [Response] First, find the positions of all the pillars in the picture. <abs_vis_token></abs_vis_token>
# 0 grounding
# [[11, 284, 312, 373], [11, 65, 386, 160]]
# [Response] Then, compare the lengths of the two pillars. It can be known that the length of troop is longer.
# [Response] Then, create a Line segment from the far right of the troop column, intersecting with the horizontal axis. <abs_vis_token></abs_vis_token>
# 2 line
# [378, 150, 383, 550]
# [Response] Your output: Then, find the intersection point of the Line with the x-axis in the image. <abs_vis_token></abs_vis_token>
# 3 grounding
# 8 [Question] Is the value of Disability-adjusted life years in Cape Verde always above 1400 from 1997 to 2007? [Answer] Yes.
# [Response] Determine the position representing Cape Verde. <abs_vis_token></abs_vis_token>
# 0 grounding
# [[45, 108, 817, 150]]
# [Response] Determine the position of the two lines at 1400. <abs_vis_token></abs_vis_token>
# 1 line
# [61, 172, 787, 178]
# [Response] By comparing Cape Verde and the 1400 Line, it is known that the Line representing Cape Verde is above the 1400 Line.
# 9 [Question] In which year, the mortality from non-communicable diseases was least in Japan? [Answer] 2005
# [Response] Your output: Firstly, locate Japan in the picture. <abs_vis_token></abs_vis_token>
# 0 grounding
# [[31, 323, 763, 401]]
# [Response] The Japanese data is gradually decreasing, reaching the lowest point on the far right.
# [Response] Secondly, draw a straight line to obtain the new image after the line is drawn. <abs_vis_token></abs_vis_token>
# 2 line
# [672, 365, 686, 560]
# [Response] The data on the far right in Japan corresponds to the year 2005.
# [Response] So, the answer is 2005.
# 10 [Question] In how many years is the value of the Georgia graph greater than 15? [Answer] 6
# [Response] Draw a straight line to obtain the new image. <abs_vis_token></abs_vis_token>
# 0 line
# [17, 234, 800, 246]
# [Response] Find the data of Georgia in img1. <abs_vis_token></abs_vis_token>
# 1 grounding
# [[19, 87, 800, 251]]
# [Response] In img1, there are 6 data points from Georgia above the Line (y=15), which means there are 6 years of data greater than 15, so the answer is: 6.
#
# After removing tool callings and coordinates:
# There are 6 data points from Georgia above the line (y=15), which means there are 6 years of data greater than 15, so the answer is: 6.
# 11 [Question] Which year recorded the highest use of Potash fertilizer by Croatia? [Answer] 2010
# [Response] Your output: Firstly, locate the Croatian Line graph in the image. <abs_vis_token></abs_vis_token>
# 0 grounding
# [[37, 59, 726, 365]]
# [Response] Output: It can be known that the position of the highest data point in the Croatian Line graph is the data point on the far left.
# [Response] Then, find the leftmost data point of the Croatian Line graph and its position. <abs_vis_token></abs_vis_token>
# 2 grounding
# [[37, 59, 726, 365], [47, 65, 78, 91]]
# [Response] Then, create a vertical segment that intersects with the horizontal axis based on the position of the leftmost data point of the Croatian Line chart. <abs_vis_token></abs_vis_token>
# 3 line
# [59, 72, 69, 590]
# [Response] Then, find the intersection point of the Line with the horizontal axis in the diagram. <abs_vis_token></abs_vis_token>
# 4 grounding
# [[33, 524, 98, 570]]
# [Response] Output: It can be known that the highest data point corresponds to the year 2010.
# [Response] So I can understand that the answer is 2010.
# 12 [Question] How many sequences have negative Influence Scores? [Answer] 2
# [Response] Draw a straight line with y=0 from a starting point to an endpoint on the current image. <abs_vis_token></abs_vis_token>
# 0 line
# [127, 402, 1815, 804]
# [Response] Find the sequences located below this one.
# [Response] Output: Through counting, such sequences have 2 in total.
# 13 [Question] For how many years has the inancial assets of private pension funds in the United States from 2000 to 2018 (in billion U.S. dollars) exceeded 9000? [Answer] three
# [Response] Draw a straight line with y=9000 to obtain a new image. <abs_vis_token></abs_vis_token>
# 0 line
# [59, 142, 734, 152]
# [Response] Framing the bar columns for each year. <abs_vis_token></abs_vis_token>
# 1 grounding
# [[115, 271, 171, 467], [173, 239, 238, 468], [238, 181, 298, 466], [296, 160, 358, 474], [359, 114, 419, 466], [423, 108, 485, 472], [486, 112, 544, 468], [544, 104, 606, 476], [604, 77, 664, 476], [667, 92, 730, 466]]
# [Response] Analyze the relationship between the value of each bar and y=9000.
# [Response] Input: Based on the positional relationship, it can be concluded that all three bar values have exceeded the Line y=9000, so the answer is three.
#
# Your output: It can be concluded that all three bar values have exceeded the Line y=9000, so the answer is three.
# 14 [Question] In which year the Sulphur dioxide emissions from china were maximum? [Answer] 2006.
# [Response] Your output: Firstly, obtain the position of the China Line. <abs_vis_token></abs_vis_token>
# 0 grounding
# 15 [Question] In how many years , the electricity generation is greater than 150 TWh in Mexico? [Answer] eight
# [Response] Your output: Firstly, locate Mexico in the picture. <abs_vis_token></abs_vis_token>
# 0 grounding
# [[76, 134, 748, 535]]
# [Response] Secondly, draw a straight line and obtain the new image after drawing the line. <abs_vis_token></abs_vis_token>
# 1 line
# [0, 245, 577, 269]
# [Response] Analyze the positional relationship between the Mexican Line graph and 150 TWh.
# [Response] The 150 TWh straight line intersects with the Mexican polyline at only one point, and since then, the values of the Mexican polyline have been greater than 150 TWh annually.
# [Response] Draw a straight line. <abs_vis_token></abs_vis_token>
# 4 line
# [543, 201, 557, 575]
# [Response] The electricity generation in Mexico started to be greater than or equal to 150 TWh in 2011.
# [Response] Locate the "2019" in the image. <abs_vis_token></abs_vis_token>
# 6 grounding
# [[635, 507, 735, 581]]
# [Response] The largest year in the graph is 2019. Therefore, Mexico's power generation was greater than or equal to 150 TWh for eight years from 2011 to 2019.
# [Response] Therefore, the answer is eight.
# 16 [Question] Which year recorded the highest percentage of Armed forces personnel in Germany? [Answer] 2002年
#
# Translation:
# In 2002.
# [Response] Firstly, obtain the position of Germany. <abs_vis_token></abs_vis_token>
# 0 grounding
# 17 [Question] How many countries have a percentage of above 60%? [Answer] 2
# [Response] First, obtain the positions of all bar charts: France is located at a specific position, the UK at another specific position, Poland at another specific position, Russia at another specific position, Spain at another specific position, and Romania at another specific position. <abs_vis_token></abs_vis_token>
# 0 grounding
# [[115, 181, 199, 471], [211, 94, 312, 474], [321, 97, 406, 472], [427, 250, 511, 477], [529, 310, 616, 472], [633, 182, 717, 470]]
# [Response] Draw a straight line to obtain a new image. <abs_vis_token></abs_vis_token>
# 1 line
# [69, 204, 741, 213]
# [Response] I understand that there are two countries with a percentage higher than 60%, so the answer is 2.
# 18 [Question] In how many years, the per capita income is more than $8000? [Answer] three
# [Response] Firstly, draw a horizontal line at the $8,000 mark. <abs_vis_token></abs_vis_token>
# 0 line
# [0, 276, 699, 286]
# [Response] Find the changing polyline in the image. <abs_vis_token></abs_vis_token>
# 1 grounding
# [[45, 49, 823, 401]]
# [Response] The trend of the polyline is showing an upward trend.
# [Response] Find the left and right parts where the Line intersects with the polyline. <abs_vis_token></abs_vis_token>
# 3 grounding
# [[0, 276, 699, 286], [45, 49, 823, 401], [33, 174, 370, 569], [394, 45, 819, 573]]
# [Response] On the left, three years were below eight thousand dollars, while on the right, three years exceeded eight thousand dollars.
# [Response] So the per capita income will exceed 8,000 US dollars in three years, hence the answer is "three".
# 19 [Question] Which year saw the lowest dropout rate in Senegal over the given years? [Answer] 1992
# [Response] Firstly, obtain the position of its corresponding map Line for Senegal. <abs_vis_token></abs_vis_token>
# 0 grounding
